# %% [markdown]
# <a href="https://colab.research.google.com/github/dundrop/IS-4487/blob/main/Lab4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # IS 4487 Module 2 Script
#
# ## Agenda
#
# - Loading installed packages
# - Inspect data
# - Explore plot types
#
# Make sure you have downloaded tonight's script and data from Canvas.

# %% [markdown]
# ##Load Libraries
#
# In this class we will be using
# - Pandas
# - Scikitlearn
# - Matplotlib
#
# We can pull sample data from
# - statsmodels.api

# %%
import pandas as pd
import matplotlib as mpl
import sklearn as sl
import plotly.express as px

# %% [markdown]
# ## Getting data into Pandas
#
# In this case we will load data from the statsmodels.org library
#
# See the Canvas assignments and lectures for a description of the Twitter data
#
# **Note:** you will need to enter a code supplied by Google in the next step.

# %%
from google.colab import drive 
drive.mount('/content/gdrive', force_remount=True)

df = pd.read_csv ('/content/gdrive/MyDrive/Colab Notebooks/Twitter_dataset.csv', encoding = 'latin1')

print (df)
# Out:
# Mounted at /content/gdrive
#       Unnamed: 0                       _id                      created_at  \
# 0              0  6020fc7e9e1aa8e3e7ad0832  Mon Feb 08 04:29:58 +0000 2021
# 1              1  6020fc7e9e1aa8e3e7ad0833  Mon Feb 08 04:29:55 +0000 2021
# 2              2  6020fc7e9e1aa8e3e7ad0834  Mon Feb 08 04:29:48 +0000 2021
# 3              3  6020fc7e9e1aa8e3e7ad0835  Mon Feb 08 04:29:43 +0000 2021
# 4              4  6020fc7e9e1aa8e3e7ad0836  Mon Feb 08 04:29:42 +0000 2021
# ...          ...                       ...                             ...
# 9750           3  6020fbb89e1aa8e3e7ac0a78  Mon Feb 08 02:01:58 +0000 2021
# 9751           4  6020fbb89e1aa8e3e7ac0a79  Mon Feb 08 01:00:24 +0000 2021
# 9752           5  6020fbb89e1aa8e3e7ac0a7a  Sun Feb 07 23:44:20 +0000 2021
# 9753           6  6020fbb89e1aa8e3e7ac0a7b  Sun Feb 07 23:33:40 +0000 2021
# 9754           7  6020fbb89e1aa8e3e7ac0a7c  Sun Feb 07 23:32:32 +0000 2021
#
#                 id        id_str  \
# 0     1.360000e+18  1.358630e+18
# 1     1.360000e+18  1.358630e+18
# 2     1.360000e+18  1.358630e+18
# 3     1.360000e+18  1.358630e+18
# 4     1.360000e+18  1.358630e+18
# ...            ...           ...
# 9750  1.360000e+18  1.358600e+18
# 9751  1.360000e+18  1.358580e+18
# 9752  1.360000e+18  1.358560e+18
# 9753  1.360000e+18  1.358560e+18
# 9754  1.360000e+18  1.358560e+18
#
#                                                    text display_text_range  \
# 0         @Rebe_Charizard ?????????????????????m(*_ _)m           [16, 45]
# 1     RT @iiiRatcha: ????????????????????"??????????...                NaN
# 2     @kashDAI not you listening to cfm and m&amp;m ...           [9, 140]
# 3     RT @_soniashenoy: M&amp;M says \nSsangyong dea...                NaN
# 4     RT @mmschocolate: This year?s #SuperBowlLV com...                NaN
# ...                                                 ...                ...
# 9750  A 5-second ad that felt like a subliminal mess...           [0, 140]
# 9751  RT @anygabrielly: Si quieres yo me quedo pa ot...                NaN
# 9752  I wonder if these Super Bowl messages of unity...                NaN
# 9753  RT @DrunkUncTony: Joe Biden's america #Unity #...                NaN
# 9754  This should be our National Anthem for 2021!\n...           [0, 140]
#
#                                                  source  truncated  \
# 0     <a href="http://twitter.com/download/iphone" r...      False
# 1     <a href="http://twitter.com/download/iphone" r...      False
# 2     <a href="http://twitter.com/download/iphone" r...       True
# 3     <a href="https://mobile.twitter.com" rel="nofo...      False
# 4     <a href="http://twitter.com/download/iphone" r...      False
# ...                                                 ...        ...
# 9750  <a href="http://twitter.com/download/android" ...       True
# 9751  <a href="http://twitter.com/download/iphone" r...      False
# 9752  <a href="http://twitter.com/download/android" ...      False
# 9753  <a href="http://tapbots.com/tweetbot" rel="nof...      False
# 9754  <a href="https://mobile.twitter.com" rel="nofo...       True
#
#       in_reply_to_status_id  ...   matching_rules  \
# 0              1.360000e+18  ...  [{'tag': None}]
# 1                       NaN  ...  [{'tag': None}]
# 2              1.360000e+18  ...  [{'tag': None}]
# 3                       NaN  ...  [{'tag': None}]
# 4                       NaN  ...  [{'tag': None}]
# ...                     ...  ...              ...
# 9750                    NaN  ...  [{'tag': None}]
# 9751                    NaN  ...  [{'tag': None}]
# 9752                    NaN  ...  [{'tag': None}]
# 9753                    NaN  ...  [{'tag': None}]
# 9754                    NaN  ...  [{'tag': None}]
#
#                                        retweeted_status  \
# 0                                                   NaN
# 1     {'created_at': 'Sun Feb 07 15:23:25 +0000 2021...
# 2                                                   NaN
# 3     {'created_at': 'Fri Feb 05 08:32:11 +0000 2021...
# 4     {'created_at': 'Wed Feb 03 15:06:02 +0000 2021...
# ...                                                 ...
# 9750                                                NaN
# 9751  {'created_at': 'Wed Jul 22 21:17:48 +0000 2020...
# 9752                                                NaN
# 9753  {'created_at': 'Sun Feb 07 23:28:35 +0000 2021...
# 9754                                                NaN
#
#                                          extended_tweet extended_entities  \
# 0                                                   NaN               NaN
# 1                                                   NaN               NaN
# 2     {'full_text': '@kashDAI not you listening to c...               NaN
# 3                                                   NaN               NaN
# 4                                                   NaN               NaN
# ...                                                 ...               ...
# 9750  {'full_text': 'A 5-second ad that felt like a ...               NaN
# 9751                                                NaN               NaN
# 9752                                                NaN               NaN
# 9753                                                NaN               NaN
# 9754  {'full_text': 'This should be our National Ant...               NaN
#
#      possibly_sensitive quoted_status_id quoted_status_id_str  \
# 0                   NaN              NaN                  NaN
# 1                   NaN              NaN                  NaN
# 2                   NaN              NaN                  NaN
# 3                   NaN              NaN                  NaN
# 4                   NaN              NaN                  NaN
# ...                 ...              ...                  ...
# 9750              False              NaN                  NaN
# 9751                NaN              NaN                  NaN
# 9752                NaN              NaN                  NaN
# 9753               True     1.360000e+18         1.358560e+18
# 9754              False              NaN                  NaN
#
#                                           quoted_status  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 9750                                                NaN
# 9751                                                NaN
# 9752                                                NaN
# 9753  {'created_at': 'Sun Feb 07 23:26:46 +0000 2021...
# 9754                                                NaN
#
#                                 quoted_status_permalink  scopes
# 0                                                   NaN     NaN
# 1                                                   NaN     NaN
# 2                                                   NaN     NaN
# 3                                                   NaN     NaN
# 4                                                   NaN     NaN
# ...                                                 ...     ...
# 9750                                                NaN     NaN
# 9751                                                NaN     NaN
# 9752                                                NaN     NaN
# 9753  {'url': 'https://t.co/St6rKn438s', 'expanded':...     NaN
# 9754                                                NaN     NaN
#
# [9755 rows x 39 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#look at the top rows
df.head(10)
# Out:
#    Unnamed: 0                       _id                      created_at  \
# 0           0  6020fc7e9e1aa8e3e7ad0832  Mon Feb 08 04:29:58 +0000 2021
# 1           1  6020fc7e9e1aa8e3e7ad0833  Mon Feb 08 04:29:55 +0000 2021
# 2           2  6020fc7e9e1aa8e3e7ad0834  Mon Feb 08 04:29:48 +0000 2021
# 3           3  6020fc7e9e1aa8e3e7ad0835  Mon Feb 08 04:29:43 +0000 2021
# 4           4  6020fc7e9e1aa8e3e7ad0836  Mon Feb 08 04:29:42 +0000 2021
# 5           5  6020fc7e9e1aa8e3e7ad0837  Mon Feb 08 04:29:40 +0000 2021
# 6           6  6020fc7e9e1aa8e3e7ad0838  Mon Feb 08 04:29:40 +0000 2021
# 7           7  6020fc7e9e1aa8e3e7ad0839  Mon Feb 08 04:29:37 +0000 2021
# 8           8  6020fc7e9e1aa8e3e7ad083a  Mon Feb 08 04:29:36 +0000 2021
# 9           9  6020fc7e9e1aa8e3e7ad083b  Mon Feb 08 04:29:35 +0000 2021
#
#              id        id_str  \
# 0  1.360000e+18  1.358630e+18
# 1  1.360000e+18  1.358630e+18
# 2  1.360000e+18  1.358630e+18
# 3  1.360000e+18  1.358630e+18
# 4  1.360000e+18  1.358630e+18
# 5  1.360000e+18  1.358630e+18
# 6  1.360000e+18  1.358630e+18
# 7  1.360000e+18  1.358630e+18
# 8  1.360000e+18  1.358630e+18
# 9  1.360000e+18  1.358630e+18
#
#                                                 text display_text_range  \
# 0      @Rebe_Charizard ?????????????????????m(*_ _)m           [16, 45]
# 1  RT @iiiRatcha: ????????????????????"??????????...                NaN
# 2  @kashDAI not you listening to cfm and m&amp;m ...           [9, 140]
# 3  RT @_soniashenoy: M&amp;M says \nSsangyong dea...                NaN
# 4  RT @mmschocolate: This year?s #SuperBowlLV com...                NaN
# 5  RT @Tezhwa: ?????????????????????????????? ???...                NaN
# 6  RT @HAIKYUUFESS: *hq contains m/m ushioi // cr...                NaN
# 7  @iDeepanshu_k @MrPiiyush @s_u_m_m_y_ @akshay_M...         [111, 140]
# 8  La neta nunca le he entendido al americano, tu...                NaN
# 9  RT @Tezhwa: ?????????????????????????????? ???...                NaN
#
#                                               source  truncated  \
# 0  <a href="http://twitter.com/download/iphone" r...      False
# 1  <a href="http://twitter.com/download/iphone" r...      False
# 2  <a href="http://twitter.com/download/iphone" r...       True
# 3  <a href="https://mobile.twitter.com" rel="nofo...      False
# 4  <a href="http://twitter.com/download/iphone" r...      False
# 5  <a href="http://twitter.com/download/android" ...      False
# 6  <a href="http://twitter.com/download/iphone" r...      False
# 7  <a href="http://twitter.com/download/android" ...      False
# 8  <a href="http://twitter.com/download/iphone" r...       True
# 9  <a href="http://twitter.com/download/iphone" r...      False
#
#    in_reply_to_status_id  ...   matching_rules  \
# 0           1.360000e+18  ...  [{'tag': None}]
# 1                    NaN  ...  [{'tag': None}]
# 2           1.360000e+18  ...  [{'tag': None}]
# 3                    NaN  ...  [{'tag': None}]
# 4                    NaN  ...  [{'tag': None}]
# 5                    NaN  ...  [{'tag': None}]
# 6                    NaN  ...  [{'tag': None}]
# 7           1.360000e+18  ...  [{'tag': None}]
# 8                    NaN  ...  [{'tag': None}]
# 9                    NaN  ...  [{'tag': None}]
#
#                                     retweeted_status  \
# 0                                                NaN
# 1  {'created_at': 'Sun Feb 07 15:23:25 +0000 2021...
# 2                                                NaN
# 3  {'created_at': 'Fri Feb 05 08:32:11 +0000 2021...
# 4  {'created_at': 'Wed Feb 03 15:06:02 +0000 2021...
# 5  {'created_at': 'Sun Feb 07 14:46:14 +0000 2021...
# 6  {'created_at': 'Sun Feb 07 14:50:59 +0000 2021...
# 7                                                NaN
# 8                                                NaN
# 9  {'created_at': 'Sun Feb 07 14:46:14 +0000 2021...
#
#                                       extended_tweet  \
# 0                                                NaN
# 1                                                NaN
# 2  {'full_text': '@kashDAI not you listening to c...
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8  {'full_text': 'La neta nunca le he entendido a...
# 9                                                NaN
#
#                                    extended_entities possibly_sensitive  \
# 0                                                NaN                NaN
# 1                                                NaN                NaN
# 2                                                NaN                NaN
# 3                                                NaN                NaN
# 4                                                NaN                NaN
# 5                                                NaN                NaN
# 6  {'media': [{'id': 1358428041433681920, 'id_str...              False
# 7                                                NaN                NaN
# 8                                                NaN                NaN
# 9                                                NaN                NaN
#
#   quoted_status_id quoted_status_id_str quoted_status  \
# 0              NaN                  NaN           NaN
# 1              NaN                  NaN           NaN
# 2              NaN                  NaN           NaN
# 3              NaN                  NaN           NaN
# 4              NaN                  NaN           NaN
# 5              NaN                  NaN           NaN
# 6              NaN                  NaN           NaN
# 7              NaN                  NaN           NaN
# 8              NaN                  NaN           NaN
# 9              NaN                  NaN           NaN
#
#    quoted_status_permalink  scopes
# 0                      NaN     NaN
# 1                      NaN     NaN
# 2                      NaN     NaN
# 3                      NaN     NaN
# 4                      NaN     NaN
# 5                      NaN     NaN
# 6                      NaN     NaN
# 7                      NaN     NaN
# 8                      NaN     NaN
# 9                      NaN     NaN
#
# [10 rows x 39 columns]

# %%
#look at last rows
df.tail(10)
# Out:
#       Unnamed: 0                       _id                      created_at  \
# 9745         120  6020fbb69e1aa8e3e7ac0706  Sun Feb 07 23:34:29 +0000 2021
# 9746         121  6020fbb69e1aa8e3e7ac0707  Sun Feb 07 23:30:04 +0000 2021
# 9747           0  6020fbb89e1aa8e3e7ac0a75  Mon Feb 08 03:16:33 +0000 2021
# 9748           1  6020fbb89e1aa8e3e7ac0a76  Mon Feb 08 02:04:19 +0000 2021
# 9749           2  6020fbb89e1aa8e3e7ac0a77  Mon Feb 08 02:03:07 +0000 2021
# 9750           3  6020fbb89e1aa8e3e7ac0a78  Mon Feb 08 02:01:58 +0000 2021
# 9751           4  6020fbb89e1aa8e3e7ac0a79  Mon Feb 08 01:00:24 +0000 2021
# 9752           5  6020fbb89e1aa8e3e7ac0a7a  Sun Feb 07 23:44:20 +0000 2021
# 9753           6  6020fbb89e1aa8e3e7ac0a7b  Sun Feb 07 23:33:40 +0000 2021
# 9754           7  6020fbb89e1aa8e3e7ac0a7c  Sun Feb 07 23:32:32 +0000 2021
#
#                 id        id_str  \
# 9745  1.360000e+18  1.358560e+18
# 9746  1.360000e+18  1.358560e+18
# 9747  1.360000e+18  1.358620e+18
# 9748  1.360000e+18  1.358600e+18
# 9749  1.360000e+18  1.358600e+18
# 9750  1.360000e+18  1.358600e+18
# 9751  1.360000e+18  1.358580e+18
# 9752  1.360000e+18  1.358560e+18
# 9753  1.360000e+18  1.358560e+18
# 9754  1.360000e+18  1.358560e+18
#
#                                                    text display_text_range  \
# 9745  @nbcsnl @danjlevy @danlevy - sad that my life ...           [18, 92]
# 9746  @soccermom0605 @JustinTrudeau @danjlevy @nbcsn...          [57, 140]
# 9747  Hey @BlueJays are you ready to play ball since...                NaN
# 9748  RT @lakeprincess22: A 5-second ad that felt li...                NaN
# 9749  RT @lakeprincess22: A 5-second ad that felt li...                NaN
# 9750  A 5-second ad that felt like a subliminal mess...           [0, 140]
# 9751  RT @anygabrielly: Si quieres yo me quedo pa ot...                NaN
# 9752  I wonder if these Super Bowl messages of unity...                NaN
# 9753  RT @DrunkUncTony: Joe Biden's america #Unity #...                NaN
# 9754  This should be our National Anthem for 2021!\n...           [0, 140]
#
#                                                  source  truncated  \
# 9745  <a href="https://mobile.twitter.com" rel="nofo...      False
# 9746  <a href="http://twitter.com/download/iphone" r...       True
# 9747  <a href="http://twitter.com/#!/download/ipad" ...      False
# 9748  <a href="http://twitter.com/download/android" ...      False
# 9749  <a href="http://twitter.com/download/iphone" r...      False
# 9750  <a href="http://twitter.com/download/android" ...       True
# 9751  <a href="http://twitter.com/download/iphone" r...      False
# 9752  <a href="http://twitter.com/download/android" ...      False
# 9753  <a href="http://tapbots.com/tweetbot" rel="nof...      False
# 9754  <a href="https://mobile.twitter.com" rel="nofo...       True
#
#       in_reply_to_status_id  ...   matching_rules  \
# 9745           1.360000e+18  ...  [{'tag': None}]
# 9746           1.360000e+18  ...  [{'tag': None}]
# 9747                    NaN  ...  [{'tag': None}]
# 9748                    NaN  ...  [{'tag': None}]
# 9749                    NaN  ...  [{'tag': None}]
# 9750                    NaN  ...  [{'tag': None}]
# 9751                    NaN  ...  [{'tag': None}]
# 9752                    NaN  ...  [{'tag': None}]
# 9753                    NaN  ...  [{'tag': None}]
# 9754                    NaN  ...  [{'tag': None}]
#
#                                        retweeted_status  \
# 9745                                                NaN
# 9746                                                NaN
# 9747                                                NaN
# 9748  {'created_at': 'Mon Feb 08 02:01:58 +0000 2021...
# 9749  {'created_at': 'Mon Feb 08 02:01:58 +0000 2021...
# 9750                                                NaN
# 9751  {'created_at': 'Wed Jul 22 21:17:48 +0000 2020...
# 9752                                                NaN
# 9753  {'created_at': 'Sun Feb 07 23:28:35 +0000 2021...
# 9754                                                NaN
#
#                                          extended_tweet extended_entities  \
# 9745                                                NaN               NaN
# 9746  {'full_text': '@soccermom0605 @JustinTrudeau @...               NaN
# 9747                                                NaN               NaN
# 9748                                                NaN               NaN
# 9749                                                NaN               NaN
# 9750  {'full_text': 'A 5-second ad that felt like a ...               NaN
# 9751                                                NaN               NaN
# 9752                                                NaN               NaN
# 9753                                                NaN               NaN
# 9754  {'full_text': 'This should be our National Ant...               NaN
#
#      possibly_sensitive quoted_status_id quoted_status_id_str  \
# 9745                NaN              NaN                  NaN
# 9746                NaN              NaN                  NaN
# 9747                NaN              NaN                  NaN
# 9748                NaN              NaN                  NaN
# 9749                NaN              NaN                  NaN
# 9750              False              NaN                  NaN
# 9751                NaN              NaN                  NaN
# 9752                NaN              NaN                  NaN
# 9753               True     1.360000e+18         1.358560e+18
# 9754              False              NaN                  NaN
#
#                                           quoted_status  \
# 9745                                                NaN
# 9746                                                NaN
# 9747                                                NaN
# 9748                                                NaN
# 9749                                                NaN
# 9750                                                NaN
# 9751                                                NaN
# 9752                                                NaN
# 9753  {'created_at': 'Sun Feb 07 23:26:46 +0000 2021...
# 9754                                                NaN
#
#                                 quoted_status_permalink  scopes
# 9745                                                NaN     NaN
# 9746                                                NaN     NaN
# 9747                                                NaN     NaN
# 9748                                                NaN     NaN
# 9749                                                NaN     NaN
# 9750                                                NaN     NaN
# 9751                                                NaN     NaN
# 9752                                                NaN     NaN
# 9753  {'url': 'https://t.co/St6rKn438s', 'expanded':...     NaN
# 9754                                                NaN     NaN
#
# [10 rows x 39 columns]

# %%
#get a summary of the dataset
df.describe()
# Out:
#         Unnamed: 0            id        id_str  in_reply_to_status_id  \
# count  9755.000000  9.755000e+03  9.755000e+03           2.862000e+03
# mean   4748.979293  1.360000e+18  1.358590e+18           1.359437e+18
# std    2813.806599  0.000000e+00  2.346899e+13           1.816500e+16
# min       0.000000  1.360000e+18  1.358560e+18           4.480000e+17
# 25%    2308.500000  1.360000e+18  1.358570e+18           1.360000e+18
# 50%    4747.000000  1.360000e+18  1.358590e+18           1.360000e+18
# 75%    7186.500000  1.360000e+18  1.358610e+18           1.360000e+18
# max    9625.000000  1.360000e+18  1.358630e+18           1.360000e+18
#
#        in_reply_to_status_id_str  in_reply_to_user_id  \
# count               2.862000e+03         2.984000e+03
# mean                1.357975e+18         7.662406e+17
# std                 1.813908e+16         5.779298e+17
# min                 4.475270e+17         2.682300e+04
# 25%                 1.358560e+18         1.400457e+09
# 50%                 1.358580e+18         1.040000e+18
# 75%                 1.358600e+18         1.282500e+18
# max                 1.358630e+18         1.360000e+18
#
#        in_reply_to_user_id_str  contributors  quote_count  reply_count  \
# count             2.984000e+03           0.0  9755.000000  9755.000000
# mean              7.663604e+17           NaN     0.024398     0.289595
# std               5.780346e+17           NaN     0.248884     1.934728
# min               2.682300e+04           NaN     0.000000     0.000000
# 25%               1.400457e+09           NaN     0.000000     0.000000
# 50%               1.041735e+18           NaN     0.000000     0.000000
# 75%               1.284912e+18           NaN     0.000000     0.000000
# max               1.358610e+18           NaN    12.000000    87.000000
#
#        retweet_count  favorite_count  quoted_status_id  quoted_status_id_str
# count    9755.000000     9755.000000      2.400000e+02          2.400000e+02
# mean        0.187596        1.862942      1.353142e+18          1.351627e+18
# std         3.435643       31.549353      5.228699e+16          5.209077e+16
# min         0.000000        0.000000      8.170000e+17          8.165590e+17
# 25%         0.000000        0.000000      1.360000e+18          1.358278e+18
# 50%         0.000000        0.000000      1.360000e+18          1.358545e+18
# 75%         0.000000        1.000000      1.360000e+18          1.358580e+18
# max       264.000000     2830.000000      1.360000e+18          1.358630e+18

# %%
#look at the datatypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9755 entries, 0 to 9754
# Data columns (total 39 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Unnamed: 0                 9755 non-null   int64
#  1   _id                        9755 non-null   object
#  2   created_at                 9755 non-null   object
#  3   id                         9755 non-null   float64
#  4   id_str                     9755 non-null   float64
#  5   text                       9755 non-null   object
#  6   display_text_range         3221 non-null   object
#  7   source                     9746 non-null   object
#  8   truncated                  9755 non-null   bool
#  9   in_reply_to_status_id      2862 non-null   float64
#  10  in_reply_to_status_id_str  2862 non-null   float64
#  11  in_reply_to_user_id        2984 non-null   float64
#  12  in_reply_to_user_id_str    2984 non-null   float64
#  13  in_reply_to_screen_name    2984 non-null   object
#  14  user                       9755 non-null   object
#  15  geo                        3 non-null      object
#  16  coordinates                3 non-null      object
#  17  place                      140 non-null    object
#  18  contributors               0 non-null      float64
#  19  is_quote_status            9755 non-null   bool
#  20  quote_count                9755 non-null   int64
#  21  reply_count                9755 non-null   int64
#  22  retweet_count              9755 non-null   int64
#  23  favorite_count             9755 non-null   int64
#  24  entities                   9755 non-null   object
#  25  favorited                  9755 non-null   bool
#  26  retweeted                  9755 non-null   bool
#  27  filter_level               9755 non-null   object
#  28  lang                       9755 non-null   object
#  29  matching_rules             9755 non-null   object
#  30  retweeted_status           4040 non-null   object
#  31  extended_tweet             950 non-null    object
#  32  extended_entities          590 non-null    object
#  33  possibly_sensitive         1166 non-null   object
#  34  quoted_status_id           240 non-null    float64
#  35  quoted_status_id_str       240 non-null    float64
#  36  quoted_status              238 non-null    object
#  37  quoted_status_permalink    238 non-null    object
#  38  scopes                     3 non-null      object
# dtypes: bool(4), float64(9), int64(5), object(21)
# memory usage: 2.6+ MB

# %% [markdown]
# #Remove @ symbols from 'text'

# %%
df['text'] = df['text'].str.replace('@', '')
df['text']
# Out:
# 0            Rebe_Charizard ?????????????????????m(*_ _)m
# 1       RT iiiRatcha: ????????????????????"???????????...
# 2       kashDAI not you listening to cfm and m&amp;m t...
# 3       RT _soniashenoy: M&amp;M says \nSsangyong deal...
# 4       RT mmschocolate: This year?s #SuperBowlLV comm...
#                               ...
# 9750    A 5-second ad that felt like a subliminal mess...
# 9751    RT anygabrielly: Si quieres yo me quedo pa otr...
# 9752    I wonder if these Super Bowl messages of unity...
# 9753    RT DrunkUncTony: Joe Biden's america #Unity #c...
# 9754    This should be our National Anthem for 2021!\n...
# Name: text, Length: 9755, dtype: object

# %% [markdown]
# #Remove rows with empty (NULL) values

# %%
removedNull = df.dropna

# %% [markdown]
# #Twitter most prevalent languages

# %%
fig = px.histogram(df, x='lang')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="e7d16cdb-02d9-44de-b121-1213bda02565" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e7d16cdb-02d9-44de-b121-1213bda02565")) {                    Plotly.newPlot(                        "e7d16cdb-02d9-44de-b121-1213bda02565",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"lang=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["ja","th","en","en","en","th","en","hi","es","th","ko","ja","en","in","in","th","en","en","ko","in","ja","ja","hi","ja","hi","en","en","en","en","en","en","ja","ja","in","en","hi","ar","ja","ht","ja","in","en","hi","hi","ja","und","ja","hi","hi","en","ja","in","en","en","ja","en","ko","en","ja","th","tr","ja","ja","en","th","ja","ja","ja","en","tl","ko","und","en","ko","und","pt","en","th","ja","hi","th","ja","ja","ja","en","en","th","en","ja","in","in","th","en","ja","th","th","th","th","en","th","th","fa","th","en","ja","ja","en","en","en","en","th","ja","ja","ja","th","ja","ja","ja","en","ja","th","ja","en","ja","ja","en","ja","ja","ko","en","th","es","en","ko","ko","ja","ja","und","hi","th","en","en","ja","ja","und","th","hi","hi","en","pt","en","und","ko","ja","ja","und","th","ja","ja","ja","en","ko","in","ja","en","ko","und","th","en","ht","es","in","en","th","th","ja","en","es","th","en","th","ja","es","th","ja","ja","es","en","th","ja","en","ja","th","es","tl","tl","en","en","zh","ja","ja","ja","en","ja","ja","ko","es","pt","ja","ja","ja","en","th","ja","ja","es","und","th","hi","th","ja","ja","en","th","ja","ja","und","ja","ja","en","ja","ja","in","th","und","fr","th","ja","ja","th","en","en","ja","ja","th","ja","ja","ja","ja","th","bn","th","ja","en","en","es","und","ja","en","ja","ja","th","th","th","th","th","th","ja","in","ja","in","ja","en","und","ko","en","th","th","ja","th","th","ja","en","ja","ja","en","th","en","en","hi","en","en","ja","ja","th","ja","ja","th","en","th","en","bn","in","en","th","en","ja","et","en","ja","th","ja","pt","ja","th","ja","ja","ja","th","th","th","ja","en","th","en","ja","th","ja","en","en","tl","ja","ja","ja","ja","tl","th","ja","ja","ja","en","th","en","th","en","ja","en","ko","th","ja","ja","en","zh","ja","en","sv","th","ja","pt","und","und","hi","th","ja","hi","ja","ja","ja","hi","pt","ja","ko","th","ja","ja","ja","und","ja","th","und","ja","hi","en","en","ja","ja","th","en","und","ja","ja","ja","hi","ja","und","th","ja","en","ja","en","ja","es","ja","ja","en","th","ja","en","th","ja","ja","ko","ja","ja","th","th","en","ja","und","ja","ja","en","ja","hi","ko","ja","ja","und","en","ja","und","und","ja","ja","en","und","hi","th","ja","en","und","ja","und","ja","hi","ur","ja","th","ja","en","en","th","ja","hi","ja","ja","en","en","ja","ja","ja","ja","ja","en","ja","ja","zh","in","ko","in","en","ja","en","th","es","ja","en","th","ko","ja","tr","hi","ja","en","ko","th","ja","en","hi","en","ja","ja","ko","ja","ja","ko","ja","und","ja","en","th","ja","ja","ja","hu","en","ja","ja","ja","und","in","th","th","en","und","en","ja","en","ja","en","ja","th","th","in","und","in","en","ja","ja","en","hi","ja","ja","en","ja","en","ja","ko","en","ja","ja","th","ht","en","ja","en","ja","th","ja","en","ja","ko","ja","ko","ja","th","en","und","en","ja","ko","ja","en","th","ja","ja","ja","en","hi","th","th","und","en","ja","ja","en","ja","ko","ja","en","en","ja","ht","en","ja","en","th","ja","ja","ja","ja","in","ja","en","ja","th","ja","ja","th","en","ja","en","hi","ja","ja","en","ja","hi","ja","und","ja","und","th","en","ja","en","en","en","th","th","es","ja","th","ja","ko","lt","ja","en","pt","en","ja","ja","und","en","ja","es","es ...

# %% [markdown]
# #Twitter scatter plot

# %%
fig = px.scatter(df, x="place", y="id_str")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="ec473483-121f-4099-87ed-a30fc2adf70a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ec473483-121f-4099-87ed-a30fc2adf70a")) {                    Plotly.newPlot(                        "ec473483-121f-4099-87ed-a30fc2adf70a",                        [{"hovertemplate":"place=%{x}<br>id_str=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","showlegend":false,"x":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"{'id': '7794ec0dd82b2b87', 'url': 'https://api.twitter.com/1.1/geo/id/7794ec0dd82b2b87.json', 'place_type': 'city', 'name': 'Gyanpur', 'full_name': 'Gyanpur, India', 'country_code': 'IN', 'country': 'India', 'bounding_box': {'type': 'Polygon', 'coordinates': [[[82.45585, 25.321139], [82.45585, 25.345377], [82.484195, 25.345377], [82.484195, 25.321139]]]}, 'attributes': {}}",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null, ...

# %%
df.describe()
# Out:
#        customer_id   postal_code     order_id  customer_id.1   order_id.1  \
# count  9569.000000   9416.000000  9569.000000    9569.000000  9569.000000
# mean    282.910962  52225.007116  5107.539450     282.910962  5107.539450
# std     199.763947  29619.544418  2043.449403     199.763947  2043.449403
# min       1.000000   1105.000000  1001.000000       1.000000  1001.000000
# 25%     127.000000  27409.000000  3393.000000     127.000000  3393.000000
# 50%     253.000000  48295.000000  5577.000000     253.000000  5577.000000
# 75%     376.000000  79923.000000  6829.000000     376.000000  6829.000000
# max     800.000000  99812.000000  8147.000000     800.000000  8147.000000
#
#         product_id     quantity  product_id.1
# count  9569.000000  9513.000000   9569.000000
# mean    106.736650     3.453380    106.736650
# std       3.694805     4.393894      3.694805
# min     101.000000     1.000000    101.000000
# 25%     104.000000     1.000000    104.000000
# 50%     107.000000     1.000000    107.000000
# 75%     110.000000     4.000000    110.000000
# max     114.000000    20.000000    114.000000

# %% [markdown]
# ## Clean up the data (Lab 3)
# Did you notice anything unusual about the "house" amounts?
#
# How about the handset price and income?

# %%
df_clean = df[(df['house'] > 0) & (df['income'] > 0) & (df['handset_price'] < 1000)]
df_clean.describe()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'house'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-91d82e0324ca> in <module>
# ----> 1 df_clean = df[(df['house'] > 0) & (df['income'] > 0) & (df['handset_price'] < 1000)]
#       2 df_clean.describe()
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'house'

# %% [markdown]
# # Add Derived Attribute
#
# Add a column with the income in K (thousands)

# %%
df_clean['income_k'] = (df_clean['income']/1000).round(2)
df_clean.head()
# Out:
# <ipython-input-12-41bea05a8bf4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['income_k'] = (df_clean['income']/1000).round(2)
#   college  income  overage  leftover   house  handset_price  \
# 0     one   23859       70         0  519105            154
# 1    zero   72466       67        16  271182            262
# 2    zero   30883       60         0  647281            211
# 3     one   44512        0        22  754958            232
# 4    zero   70535        0         0  653421            310
#
#    over_15mins_calls_per_month  average_call_duration reported_satisfaction  \
# 0                          5.0                      8                   low
# 1                          5.0                      5                   low
# 2                          3.0                      8                   low
# 3                          0.0                      5                   low
# 4                          0.0                     14                   low
#
#   reported_usage_level considering_change_of_plan  leave     id  income_k
# 0                  low                        yes  LEAVE   8183     23.86
# 1                  low                        yes  LEAVE  12501     72.47
# 2                  low                        yes   STAY   7425     30.88
# 3                  low                         no  LEAVE  13488     44.51
# 4                  low                        yes   STAY  11389     70.54

# %% [markdown]
# ## Slice the data
#  What is average house price at the two levels of leave?
#
#  Conclusion?  Stayers have substantially more expensive homes.

# %%
df_clean[['house','leave']].groupby('leave').mean().round(2)
# Out:
#            house
# leave
# LEAVE  439255.26
# STAY   547591.97
